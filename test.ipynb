# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("microsoft/harrier-oss-v1-0.6b", 
                            model_kwargs={"dtype": "auto"}, 
                            # cache_folder='C:/Users/Mitali B/OneDrive/Desktop/AI_AT3_Database/model_cache'
                            )
# Out:
# Loading weights: 100%|██████████| 310/310 [00:00<00:00, 8152.86it/s]

# %%
from pathlib import Path
model.save(Path('local_model'))
# Out:
# Writing model shards: 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]

# %%
import chromadb
from chromadb.config import Settings

# Clear any existing client instances
chromadb.api.client.SharedSystemClient.clear_system_cache()

# %%
import importlib
import vector_store
importlib.reload(vector_store)

from vector_store import ChromaVectorStore

# %%
# testing out class
from vector_store import ChromaVectorStore
import os
from pathlib import Path

persist_directory = "vdb"
embedding_model_name = "local_model"
chroma_vdb = ChromaVectorStore(
        collection_name = 'tenancy_documents',
        persist_directory = persist_directory,
        embedding_model_name = embedding_model_name
)
# Out:
# Module cwd: c:\Users\Mitali B\OneDrive\Desktop\AI_AT3_Database
# Resolved path: c:\Users\Mitali B\OneDrive\Desktop\AI_AT3_Database\vdb
# Loading weights: 100%|██████████| 310/310 [00:00<00:00, 6599.03it/s]

# %%
query = "I have a question about share housing, can I sub-lease a room?"
chroma_vdb.query(query, top_k = 2)
# Out:
# [{'id': 'id2',
#   'document': 'This is a document about sub-leasing rooms in an apartment/house where people are living and regarding rent conditions there',
#   'metadata': {'source': 'NSW Government',
#    'type': 'Share Housing Rules',
#    'jurisdiction': 'NSW'},
#   'distance': 0.4898339807987213},
#  {'id': 'id4',
#   'document': 'The landlord is not allowed to increase rent by more than 10% in a financial year.',
#   'metadata': {'jurisdiction': 'NSW',
#    'type': 'Rent Increase',
#    'source': 'NSW Government'},
#   'distance': 0.7811493873596191}]

# %%
chroma_vdb.count
# Out:
# 4
